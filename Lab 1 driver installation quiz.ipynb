# %% [markdown]
# # Lab 1 Driver Installation Quiz
#
# This quiz tests your knowledge from Lab 1 - Driver Installation.

# %%
# Install jupyterquiz if not already installed
# !pip install jupyterquiz

# %%
from jupyterquiz import display_quiz
import json

# Load the questions from the JSON file
with open("materials/lab1_quiz.json", "r") as f:
    questions = json.load(f)

# Display the quiz with preserve_responses=True to output results for grading
display_quiz(questions, preserve_responses=True)
